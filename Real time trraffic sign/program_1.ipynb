# %%
from ultralytics import YOLO
model_1 = YOLO('my model.pt')

# %%
import cv2


class_names = ['-', '0', 'Barrier Ahead', 'Cattle', 'Caution', 'Cycle Crossing', 'Dangerous Dip', 'Eating Place', 'Falling Rocks', 'Ferry', 'First Aid Post', 'Give Way', 'Horn Prohibited', 'Hospital', 'Hump', 'Left Hair Pin Bend', 'Left Reverse Bend', 'Left hand curve', 'Light Refreshment', 'Men at Work', 'Narrow Bridge', 'Narrow road ahead', 'No Parking', 'No Stopping', 'No Thorough Road', 'No Thorough SideRoad', 'Parking Lot Cars', 'Parking Lot Cycle', 'Parking Lot Scooter and MotorCycle', 'Parking This side', 'Pedestrian Crossing', 'Pedestrian Prohibited', 'Petrol Pump- Gas Station', 'Public Telephone', 'Resting Place', 'Right Hair Pin Bend', 'Right Hand Curve', 'Right Reverse Bend', 'Road Wideness Ahead', 'Round About', 'School Ahead', 'Slippery Road', 'Speed Limit -10-', 'Speed Limit -100-', 'Speed Limit -110-', 'Speed Limit -120-', 'Speed Limit -130-', 'Speed Limit -140-', 'Speed Limit -150-', 'Speed Limit -160-', 'Speed Limit -20-', 'Speed Limit -25-', 'Speed Limit -35-', 'Speed Limit -45-', 'Speed Limit -48-', 'Speed Limit -5-', 'Speed Limit -50-', 'Speed Limit -55-', 'Speed Limit -60-', 'Speed Limit -65-', 'Speed Limit -70-', 'Speed Limit -75-', 'Speed Limit -8-', 'Speed Limit -80-', 'Speed Limit -90-', 'Speed Limit 3', 'Speed Limit 30', 'Speed limit -15-', 'Speed limit -40-', 'Steep Ascent', 'Steep Desecnt', 'Stop', 'Straight Prohibitor No Entry', 'walking']


cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        print("Failed to grab frame")
        break

   
    results = model_1(frame)
    boxes = results[0].boxes  

    for box in boxes:
        cls = int(box.cls.item())         
        conf = box.conf.item()            
        x1, y1, x2, y2 = [int(coord.item()) for coord in box.xyxy[0]]  

        label_name = class_names[cls] if cls < len(class_names) else f"Class {cls}"
        label = f"{label_name}: {conf:.2f}"

        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    cv2.imshow("Traffic Sign Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 0, 172.5ms
# Speed: 9.5ms preprocess, 172.5ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 167.0ms
# Speed: 1.6ms preprocess, 167.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 167.8ms
# Speed: 3.3ms preprocess, 167.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 142.1ms
# Speed: 1.6ms preprocess, 142.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 117.3ms
# Speed: 1.2ms preprocess, 117.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 119.0ms
# Speed: 1.3ms preprocess, 119.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 144.0ms
# Speed: 2.3ms preprocess, 144.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 140.8ms
# Speed: 4.1ms preprocess, 140.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 131.4ms
# Speed: 3.9ms preprocess, 131.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 169.7ms
# Speed: 2.7ms preprocess, 169.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 152.8ms
# Speed: 4.2ms preprocess, 152.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 155.8ms
# Speed: 3.6ms preprocess, 155.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 161.8ms
# Speed: 1.3ms preprocess, 161.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 152.7ms
# Speed: 4.5ms preprocess, 152.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 151.8ms
# Speed: 1.7ms preprocess, 151.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 113.7ms
# Speed: 3.8ms preprocess, 113.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 164.4ms
# Speed: 2.4ms preprocess, 164.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 143.8ms
# Speed: 3.1ms preprocess, 143.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 140.0ms
# Speed: 4.1ms preprocess, 140.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 173.0ms
# Speed: 3.5ms preprocess, 173.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 150.8ms
# Speed: 1.4ms preprocess, 150.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 182.4ms
# Speed: 3.1ms preprocess, 182.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 171.9ms
# Speed: 4.7ms preprocess, 171.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 162.6ms
# Speed: 2.5ms preprocess, 162.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 149.2ms
# Speed: 2.3ms preprocess, 149.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 168.6ms
# Speed: 2.0ms preprocess, 168.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections),